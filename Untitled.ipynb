# %%
import pandas as pd

# %%
df = pd.read_csv('poker_now_log_11-30_g2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2839 entries, 0 to 2838
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   entry   2839 non-null   object
#  1   at      2839 non-null   object
#  2   order   2839 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 66.7+ KB

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                                                                                                                                                                                      entry  \
# 0                                                                                                                          The player "Rod @ juakLvqGHM" quits the game with a stack of 0.
# 1                                                                                                                        The player "CStam @ O7yGfPfnlh" quits the game with a stack of 0.
# 2                                                                                                                                                                   -- ending hand #148 --
# 3                                                                                            "McNeal @ 2VIQ_H6NmI" collected 1136 from pot with Straight (combination: 9♥, 8♠, 7♠, 6♠, 5♦)
# ...

# %%
df[df['entry']
# Out:
#   File "C:\Users\rober\AppData\Local\Temp/ipykernel_9488/3404249156.py", line 1
#     df[df['entry']
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
df_player_action = df[df['entry'].str[0] == '"']

# %%
df_player_action['player'] = df_player_action['entry'].str.split('"').str.get(1).str.split('@').str.get(0)
# Out:
# C:\Users\rober\AppData\Local\Temp/ipykernel_9488/1538605040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_player_action['player'] = df_player_action['entry'].str.split('"').str.get(1).str.split('@').str.get(0)

# %%
df_player_action['action'] = df_player_action['entry'].str.split('"').str.get(2).str.split(" ").str.get(1)
# Out:
# C:\Users\rober\AppData\Local\Temp/ipykernel_9488/2725259236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_player_action['action'] = df_player_action['entry'].str.split('"').str.get(2).str.split(" ").str.get(1)

# %%
df_player_action.head()
# Out:
#                                                                                              entry  \
# 2  "McNeal @ 2VIQ_H6NmI" collected 2752 from pot with Pair, 9's (combination: 9♥, 9♣, A♣, 10♦, 8♦)
# 6                                                            "McNeal @ 2VIQ_H6NmI" shows a 9♥, 7♦.
# 7                                                           "th3y3ti @ CLMXfwMI0O" shows a 4♦, 5♦.
# 8                                                                 "McNeal @ 2VIQ_H6NmI" calls 1376
# 9                                              "th3y3ti @ CLMXfwMI0O" raises to 1376 and go all in
#
#                          at            order    player     action
# 2  2022-12-01T02:54:18.057Z  166986325805700   McNeal   collected
# 6  2022-12-01T02:54:01.834Z  166986324183401   McNeal       shows
# 7  2022-12-01T02:54:01.834Z  166986324183400  th3y3ti       shows
# 8  2022-12-01T02:54:00.993Z  166986324099300   McNeal       calls
# ...

# %%
df_player_action[df_player_action['action'] == 'collected'].groupby(['player', 'action']).size()
# Out:
# player    action
# CStam     collected    16
# McNeal    collected    24
# Rod       collected    18
# Ruthie    collected    13
# th3y3ti   collected    34
# dtype: int64

# %%
df_player_action.groupby(['action','player']).size()
# Out:
# action     player
# bets       CStam       18
#            McNeal       8
#            Rod          8
#            Ruthie      10
#            th3y3ti     16
# calls      CStam       17
#            McNeal      35
#            Rod         25
#            Ruthie      18
#            th3y3ti     30
# checks     CStam       13
#            McNeal      30
#            Rod         18
#            Ruthie      13
#            th3y3ti     22
# collected  CStam       16
#            McNeal      24
#            Rod         18
#            Ruthie      13
#            th3y3ti     34
# folds      CStam       47
#            McNeal      67
#            Rod         62
#            Ruthie      60
#            th3y3ti     51
# posts      CStam       28
#            McNeal      48
#            Rod         37
#            Ruthie      31
#            th3y3ti     46
# raises     CStam       14
#            McNeal      13
#            Rod         15
#            Ruthie       4
#            th3y3ti     27
# ...

# %%
df['entry'].str[0]
# Out:
# 0       T
# 1       -
# 2       "
# 3       R
# 4       T
# 5       F
# 6       "
# 7       "
# 8       "
# 9       "
# 10      "
# 11      "
# 12      Y
# 13      P
# 14      -
# 15      -
# 16      "
# 17      R
# 18      T
# 19      F
# 20      "
# 21      "
# 22      U
# 23      "
# 24      "
# 25      "
# 26      Y
# 27      P
# 28      -
# 29      -
# 30      "
# 31      R
# 32      T
# 33      F
# 34      "
# 35      "
# 36      "
# 37      "
# 38      "
# 39      "
# 40      Y
# 41      P
# 42      -
# 43      "
# 44      -
# 45      "
# 46      U
# 47      "
# 48      "
# 49      "
# 50      F
# 51      "
# 52      "
# 53      "
# 54      "
# 55      Y
# 56      P
# 57      -
# 58      U
# 59      "
# 60      "
# 61      -
# 62      "
# 63      U
# 64      "
# 65      "
# 66      "
# 67      F
# 68      "
# 69      "
# 70      "
# 71      "
# 72      Y
# 73      P
# 74      -
# 75      -
# 76      "
# 77      R
# 78      T
# 79      F
# 80      "
# 81      "
# 82      "
# ...

# %%
df_player_action['entry'].value_counts()
# Out:
# "McNeal @ 2VIQ_H6NmI" folds                                                                                      67
# "Rod @ juakLvqGHM" folds                                                                                         62
# "Ruthie @ BQ7aBApX8b" folds                                                                                      60
# "th3y3ti @ CLMXfwMI0O" folds                                                                                     51
# "CStam @ O7yGfPfnlh" folds                                                                                       47
# "McNeal @ 2VIQ_H6NmI" checks                                                                                     30
# "th3y3ti @ CLMXfwMI0O" checks                                                                                    22
# "Rod @ juakLvqGHM" checks                                                                                        18
# ...

# %%
df_player_action['entry'].str.rsplit('@')
# Out:
# 2                     ["McNeal ,  2VIQ_H6NmI" collected 2752 from pot with Pair, 9's (combination: 9♥, 9♣, A♣, 10♦, 8♦)]
# 6                                                                               ["McNeal ,  2VIQ_H6NmI" shows a 9♥, 7♦.]
# 7                                                                              ["th3y3ti ,  CLMXfwMI0O" shows a 4♦, 5♦.]
# 8                                                                                    ["McNeal ,  2VIQ_H6NmI" calls 1376]
# 9                                                                 ["th3y3ti ,  CLMXfwMI0O" raises to 1376 and go all in]
# 10                                                                     ["McNeal ,  2VIQ_H6NmI" posts a big blind of 800]
# 11                                                                  ["th3y3ti ,  CLMXfwMI0O" posts a small blind of 400]
# 16          ["th3y3ti ,  CLMXfwMI0O" collected 1376 from pot with Two Pair, 8's & 5's (combination: 8♦, 8♣, 5♠, 5♣, Q♥)]
# ...

# %%
df_player_action['entry'].str.split('"')
